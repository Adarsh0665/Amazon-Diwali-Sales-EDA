# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("anandshaw2001/amazon-product-sales-2025")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: C:\Users\Adarsh\.cache\kagglehub\datasets\anandshaw2001\amazon-product-sales-2025\versions\1

# %%
path
# Out:
# 'C:\\Users\\Adarsh\\.cache\\kagglehub\\datasets\\anandshaw2001\\amazon-product-sales-2025\\versions\\1'

# %%
import os
for i in os.listdir(path):
    print(i)
# Out:
# amazon_sales_2025_INR.csv

# %%
file_path = path +"/amazon_sales_2025_INR.csv"
sales=pd.read_csv(file_path)

# %%
sales
# Out:
#         Order_ID        Date Customer_ID Product_Category      Product_Name  \
# 0      ORD100000  2025-01-25    CUST2796   Home & Kitchen      Cookware Set
# 1      ORD100001  2025-08-28    CUST9669           Beauty        Hair Dryer
# 2      ORD100002  2025-02-27    CUST5808      Electronics            Tablet
# 3      ORD100003  2025-02-24    CUST5889      Electronics        Headphones
# 4      ORD100004  2025-06-15    CUST9005         Clothing             Saree
# ...          ...         ...         ...              ...               ...
# 14995  ORD114995  2025-04-12    CUST2822           Beauty          Lipstick
# 14996  ORD114996  2025-08-29    CUST6143           Beauty           Shampoo
# 14997  ORD114997  2025-01-27    CUST6747            Books  Science Textbook
# 14998  ORD114998  2025-06-21    CUST2748           Beauty        Hair Dryer
# 14999  ORD114999  2025-08-07    CUST9174   Home & Kitchen     Mixer Grinder
#
# ...

# %%
sales.head()
# Out:
#     Order_ID        Date Customer_ID Product_Category  Product_Name  Quantity  \
# 0  ORD100000  2025-01-25    CUST2796   Home & Kitchen  Cookware Set         2
# 1  ORD100001  2025-08-28    CUST9669           Beauty    Hair Dryer         1
# 2  ORD100002  2025-02-27    CUST5808      Electronics        Tablet         3
# 3  ORD100003  2025-02-24    CUST5889      Electronics    Headphones         5
# 4  ORD100004  2025-06-15    CUST9005         Clothing         Saree         5
#
#    Unit_Price_INR  Total_Sales_INR    Payment_Method Delivery_Status  \
# 0        25574.41         51148.82       Credit Card        Returned
# 1        19361.41         19361.41        Debit Card        Returned
# 2        38476.22        115428.66  Cash on Delivery       Delivered
# 3        38145.72        190728.60       Credit Card       Delivered
# 4        45940.98        229704.90               UPI       Delivered
#
#    Review_Rating         Review_Text      State Country
# ...

# %%
sales.tail()
# Out:
#         Order_ID        Date Customer_ID Product_Category      Product_Name  \
# 14995  ORD114995  2025-04-12    CUST2822           Beauty          Lipstick
# 14996  ORD114996  2025-08-29    CUST6143           Beauty           Shampoo
# 14997  ORD114997  2025-01-27    CUST6747            Books  Science Textbook
# 14998  ORD114998  2025-06-21    CUST2748           Beauty        Hair Dryer
# 14999  ORD114999  2025-08-07    CUST9174   Home & Kitchen     Mixer Grinder
#
#        Quantity  Unit_Price_INR  Total_Sales_INR    Payment_Method  \
# 14995         4        36421.54        145686.16               UPI
# 14996         4        18158.02         72632.08        Debit Card
# 14997         1        38864.05         38864.05               UPI
# 14998         3        32658.62         97975.86  Cash on Delivery
# 14999         5        45005.57        225027.85  Cash on Delivery
#
#       Delivery_Status  Review_Rating                 Review_Text  \
# ...

# %%
sales.shape
# Out:
# (15000, 14)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          15000 non-null  object
#  1   Date              15000 non-null  object
#  2   Customer_ID       15000 non-null  object
#  3   Product_Category  15000 non-null  object
#  4   Product_Name      15000 non-null  object
#  5   Quantity          15000 non-null  int64
#  6   Unit_Price_INR    15000 non-null  float64
#  7   Total_Sales_INR   15000 non-null  float64
#  8   Payment_Method    15000 non-null  object
#  9   Delivery_Status   15000 non-null  object
#  10  Review_Rating     15000 non-null  int64
#  11  Review_Text       15000 non-null  object
#  12  State             15000 non-null  object
#  13  Country           15000 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 1.6+ MB

# %%
sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
sales.isnull().head()
# Out:
#    Order_ID   Date  Customer_ID  Product_Category  Product_Name  Quantity  \
# 0     False  False        False             False         False     False
# 1     False  False        False             False         False     False
# 2     False  False        False             False         False     False
# 3     False  False        False             False         False     False
# 4     False  False        False             False         False     False
#
#    Unit_Price_INR  Total_Sales_INR  Payment_Method  Delivery_Status  \
# 0           False            False           False            False
# 1           False            False           False            False
# 2           False            False           False            False
# 3           False            False           False            False
# 4           False            False           False            False
#
#    Review_Rating  Review_Text  State  Country
# 0          False        False  False    False
# ...

# %%
sales.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14995    False
# 14996    False
# 14997    False
# 14998    False
# 14999    False
# Length: 15000, dtype: bool

# %%
sales.head()
# Out:
#     Order_ID        Date Customer_ID Product_Category  Product_Name  Quantity  \
# 0  ORD100000  2025-01-25    CUST2796   Home & Kitchen  Cookware Set         2
# 1  ORD100001  2025-08-28    CUST9669           Beauty    Hair Dryer         1
# 2  ORD100002  2025-02-27    CUST5808      Electronics        Tablet         3
# 3  ORD100003  2025-02-24    CUST5889      Electronics    Headphones         5
# 4  ORD100004  2025-06-15    CUST9005         Clothing         Saree         5
#
#    Unit_Price_INR  Total_Sales_INR    Payment_Method Delivery_Status  \
# 0        25574.41         51148.82       Credit Card        Returned
# 1        19361.41         19361.41        Debit Card        Returned
# 2        38476.22        115428.66  Cash on Delivery       Delivered
# 3        38145.72        190728.60       Credit Card       Delivered
# 4        45940.98        229704.90               UPI       Delivered
#
#    Review_Rating         Review_Text      State Country
# ...

# %%
sales["Country"].value_counts()
# Out:
# Country
# India    15000
# Name: count, dtype: int64

# %%
sales.drop(columns=["Customer_ID","Review_Text","Country"],inplace=True)

# %%
sales.head()
# Out:
#     Order_ID        Date Product_Category  Product_Name  Quantity  \
# 0  ORD100000  2025-01-25   Home & Kitchen  Cookware Set         2
# 1  ORD100001  2025-08-28           Beauty    Hair Dryer         1
# 2  ORD100002  2025-02-27      Electronics        Tablet         3
# 3  ORD100003  2025-02-24      Electronics    Headphones         5
# 4  ORD100004  2025-06-15         Clothing         Saree         5
#
#    Unit_Price_INR  Total_Sales_INR    Payment_Method Delivery_Status  \
# 0        25574.41         51148.82       Credit Card        Returned
# 1        19361.41         19361.41        Debit Card        Returned
# 2        38476.22        115428.66  Cash on Delivery       Delivered
# 3        38145.72        190728.60       Credit Card       Delivered
# 4        45940.98        229704.90               UPI       Delivered
#
#    Review_Rating      State
# 0              1     Sikkim
# 1              5  Telangana
# 2              3   Nagaland
# 3              5      Assam
# ...

# %%
sales.shape
# Out:
# (15000, 11)

# %%
sales.head()
# Out:
#     Order_ID        Date Product_Category  Product_Name  Quantity  \
# 0  ORD100000  2025-01-25   Home & Kitchen  Cookware Set         2
# 1  ORD100001  2025-08-28           Beauty    Hair Dryer         1
# 2  ORD100002  2025-02-27      Electronics        Tablet         3
# 3  ORD100003  2025-02-24      Electronics    Headphones         5
# 4  ORD100004  2025-06-15         Clothing         Saree         5
#
#    Unit_Price_INR  Total_Sales_INR    Payment_Method Delivery_Status  \
# 0        25574.41         51148.82       Credit Card        Returned
# 1        19361.41         19361.41        Debit Card        Returned
# 2        38476.22        115428.66  Cash on Delivery       Delivered
# 3        38145.72        190728.60       Credit Card       Delivered
# 4        45940.98        229704.90               UPI       Delivered
#
#    Review_Rating      State
# 0              1     Sikkim
# 1              5  Telangana
# 2              3   Nagaland
# 3              5      Assam
# ...

# %% [markdown]
# # State-wise_Sales_Contribution

# %%
state_wise_sales=sales.groupby('State', as_index=False)['Total_Sales_INR'].sum()
state_wise_sales.head(10)
# Out:
#                State  Total_Sales_INR
# 0     Andhra Pradesh      36237577.25
# 1  Arunachal Pradesh      39348777.94
# 2              Assam      38739460.17
# 3              Bihar      41669240.44
# 4       Chhattisgarh      42857545.27
# 5                Goa      40488243.03
# 6            Gujarat      36226185.91
# 7            Haryana      39171925.41
# 8   Himachal Pradesh      38182171.87
# 9          Jharkhand      39606674.07

# %%
state_wise_sales.tail(10)
# Out:
#             State  Total_Sales_INR
# 18         Odisha      40924381.38
# 19         Punjab      39640897.69
# 20      Rajasthan      42906175.08
# 21         Sikkim      43113469.51
# 22     Tamil Nadu      41967968.99
# 23      Telangana      39077114.06
# 24        Tripura      41103376.81
# 25  Uttar Pradesh      41690917.07
# 26    Uttarakhand      37633617.48
# 27    West Bengal      41195932.45

# %%
state_sales=sales.groupby('State')['Total_Sales_INR'].sum()
plt.figure()
plt.pie(
    state_sales,
    labels=state_sales.index,
    autopct='%1.1f%%',
    startangle=90)
plt.title('State-wise_Sales_Contribution')
plt.show()

# %%
state_sales=sales.groupby('State')['Total_Sales_INR'].sum()
top_5_states= state_sales.sort_values(ascending=False).head(5)
plt.figure()
plt.pie(
    top_5_states,
    labels=top_5_states.index,
    autopct='%1.1f%%',
    startangle=90)
plt.title('Top-5_States_Contribution')
plt.show()

# %% [markdown]
# # Unit Price vs Total Sales

# %%
hist = ['Unit_Price_INR','Total_Sales_INR']
for col in hist:
    plt.subplot(1,2,hist.index(col)+1)
    sns.histplot(sales[col],kde=True )
plt.show()

# %% [markdown]
# # Products Data Distribution

# %%
columns = ['Quantity', 'Unit_Price_INR', 'Total_Sales_INR', 'Review_Rating']
for col in columns:
    plt.figure(figsize=(4,2))
    sns.histplot(sales[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
category_col = ['Product_Category', 'Payment_Method', 'Delivery_Status', 'State']
for col in category_col:
    plt.figure(figsize=(7,3))
    sns.countplot(data=sales, x=col, order=sales[col].value_counts().index)
    plt.title(f'{col} Distribution')
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# # Top Products BY Sales

# %%
Top_Products = sales.groupby('Product_Name')['Total_Sales_INR'].sum().sort_values(ascending=False).head(20)
sns.barplot(x=Top_Products.index, y=Top_Products.values)
plt.ylabel("Total Sales (INR)")
plt.xlabel("Product Name")
plt.yscale("log")
plt.xticks(rotation=90)
plt.title("Top 20 Products by Total Sales")
plt.show()

# %% [markdown]
# # Total Sales by Category

# %%
plt.figure(figsize=(8,4))
sns.barplot(data=sales, x='Product_Category', y='Total_Sales_INR', estimator=sum)
plt.title('Total Sales by Product Category')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.barplot(data=sales, x='Product_Category', y='Review_Rating')
plt.title('Customer Ratings by Category')
plt.show()

# %% [markdown]
# # Monthly Sales Trend

# %%
sales['Date'] = pd.to_datetime(sales['Date'])
sales['Month'] = sales['Date'].dt.month_name()
plt.figure(figsize=(10,4))
sns.barplot(data=sales, x='Month', y='Total_Sales_INR',estimator=sum)
plt.title('Monthly Sales Trend')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Sales by Payment Method

# %%
payment = sales.groupby('Payment_Method')['Total_Sales_INR'].sum().sort_values(ascending=False)
sns.lineplot(x=payment.index, y=payment.values,)
plt.ylabel("Total Sales INR")
plt.xlabel("Payment Method")
plt.xticks(rotation=90)
plt.title("Total Sales by Payment Method")
plt.show()

# %% [markdown]
# # Return Data

# %%
returns_category = sales.groupby('Product_Category')['Delivery_Status'].apply(lambda x: (x=='Returned').mean()*100)
returns_category.sort_values(ascending=False).plot(kind='bar', figsize=(8,4))
plt.title('Return Rate by Product Category (%)')
plt.ylabel('Return %')
plt.show()

# %%
returns_category = sales.groupby('State')['Delivery_Status'].apply(lambda x: (x=='Returned').mean()*100)
plt.figure(figsize=(8,4))
sns.lineplot(x=returns_category.index, y=returns_category.values)
plt.title('Return Rate by State (%)')
plt.xlabel('State')
plt.ylabel('Return %')
plt.xticks(rotation=90)
plt.show()

# %%
returns_category = sales.groupby('Review_Rating')['Delivery_Status'].apply(lambda x: (x=='Returned').mean()*100)
returns_category.sort_values(ascending=False).plot(kind='bar', figsize=(8,4))
plt.title('Return Rate by ratings (%)')
plt.ylabel('Return %')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Rating by ProductName

# %%
#plt.figure(figsize=(10,4))
#sns.barplot(data=sales, x='Product_Name', y='Review_Rating', estimator='mean', order=sales.groupby('Product_Name')['Review_Rating'].mean().sort_values(ascending=False).index)
#plt.title('Average Rating by ProductName')
#plt.xticks(rotation=90)
#plt.show()
rating_sorted = sales.groupby('Product_Name')['Review_Rating'].mean().sort_values(ascending=False)

plt.figure(figsize=(10,4))
plt.plot(
    rating_sorted.index,
    rating_sorted.values,
    marker='o'
)
plt.title('Average Rating Trend Across Products')
plt.xlabel('Product Name')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %% [markdown]
# # Average Rating by State

# %%
plt.figure(figsize=(10,4))
sns.lineplot(data=sales ,x='State', y='Review_Rating')
plt.title('Average Rating by State')
plt.xticks(rotation=90)
plt.show()
